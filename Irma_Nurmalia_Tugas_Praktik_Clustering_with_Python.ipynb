# %% [markdown]
# <a href="https://colab.research.google.com/github/girlwholoved/Task1-TitanicDataset/blob/main/Irma_Nurmalia_Tugas_Praktik_Clustering_with_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
import xgboost as xgb
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data_uncleaned = pd.read_csv('/content/drive/MyDrive/#dataSET-MSIB/titanic-train.csv')
data_uncleaned.set_index('PassengerId', inplace=True) # menjadikan kolom 'PassengerId' sebagai index
data_uncleaned
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %%
data_uncleaned.isna().sum()
# untuk mengetahui berapa banyak data yang kosong pada data set
# Out:
# Survived      0
# Pclass        0
# Name          0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Ticket        0
# Fare          0
# Cabin       687
# Embarked      2
# dtype: int64

# %%
data = data_uncleaned.fillna(0)
data

# melakukan cleaning data --> data NaN diganti dengan '0'
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %%
data.info()

# untuk mencari tahu data mana saja yang berupa string --> clasification tidak bisa menggunakan data string --> bisa saja namun harus diganti jadi numerik
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 891 entries, 1 to 891
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Pclass    891 non-null    int64
#  2   Name      891 non-null    object
#  3   Sex       891 non-null    object
#  4   Age       891 non-null    float64
#  5   SibSp     891 non-null    int64
#  6   Parch     891 non-null    int64
#  7   Ticket    891 non-null    object
#  8   Fare      891 non-null    float64
#  9   Cabin     891 non-null    object
#  10  Embarked  891 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 83.5+ KB

# %%
X = data.drop(['Survived', 'Name', 'Ticket', 'Cabin', 'Embarked', 'Sex'], axis=1)
y = data['Survived']

X

# X = semua kolom digunakan kecuali yang sudah di drop --> data yang berisi faktor-faktor apa saja yang memengaruhi kelompok klasifikasi
# y = pengklasifikasian berdasarkan apa --> pada data ini pengklasifikasian penumpang atau "PassengerId" berdasarkan label 'Survived'
# Out:
#              Pclass   Age  SibSp  Parch     Fare
# PassengerId
# 1                 3  22.0      1      0   7.2500
# 2                 1  38.0      1      0  71.2833
# 3                 3  26.0      0      0   7.9250
# 4                 1  35.0      1      0  53.1000
# 5                 3  35.0      0      0   8.0500
# ...             ...   ...    ...    ...      ...
# 887               2  27.0      0      0  13.0000
# 888               1  19.0      0      0  30.0000
# 889               3   0.0      1      2  23.4500
# 890               1  26.0      0      0  30.0000
# 891               3  32.0      0      0   7.7500
#
# [891 rows x 5 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=41)

# test_size = 0,25 --> 20:80 (data_train:data_testing)
# random_test = parameter untuk mengontrol RANDOMNESS --> agar pembagian data konsisten

# %%
X_test
# Out:
#              Pclass   Age  SibSp  Parch      Fare
# PassengerId
# 455               3   0.0      0      0    8.0500
# 625               3  21.0      0      0   16.1000
# 538               1  30.0      0      0  106.4250
# 686               2  25.0      1      2   41.5792
# 397               3  31.0      0      0    7.8542
# ...             ...   ...    ...    ...       ...
# 284               3  19.0      0      0    8.0500
# 186               1   0.0      0      0   50.0000
# 352               1   0.0      0      0   35.0000
# 351               3  23.0      0      0    9.2250
# 448               1  34.0      0      0   26.5500
#
# [223 rows x 5 columns]

# %%
y_test
# Out:
# PassengerId
# 455    0
# 625    0
# 538    1
# 686    0
# 397    0
#       ..
# 284    1
# 186    0
# 352    0
# 351    0
# 448    1
# Name: Survived, Length: 223, dtype: int64

# %%
# Fungsi di bawah ini berfungsi untuk melakukann prediksi dengan berbagai jenis model klasifikasi, yakni K-nearest neighbors, decision tree, random forest, XGBoost

# K-Nearest Neighbors (KNN)
knn = KNeighborsClassifier(n_neighbors=5) # dibagi ke dalam 5 kelompok
knn.fit(X_train, y_train)
knn_pred = knn.predict(X_test)

# Decision Tree
dt = DecisionTreeClassifier()
dt.fit(X_train, y_train)
dt_pred = dt.predict(X_test)

# Random Forest
rf = RandomForestClassifier()
rf.fit(X_train, y_train)
rf_pred = rf.predict(X_test)

# XGBoost
xgb_model = xgb.XGBClassifier()
xgb_model.fit(X_train, y_train)
xgb_pred = xgb_model.predict(X_test)

# %%
actual = y_test  # Actual target values
# Create confusion matrices
knn_cm = confusion_matrix(actual, knn_pred)
dt_cm = confusion_matrix(actual, dt_pred)
rf_cm = confusion_matrix(actual, rf_pred)
xgb_cm = confusion_matrix(actual, xgb_pred)

# Convert confusion matrices to DataFrames
def confusion_matrix_to_dataframe(cm):
    labels = sorted(set(actual))
    df_cm = pd.DataFrame(cm, index=labels, columns=labels)
    df_cm.index.name = 'Actual'
    df_cm.columns.name = 'Predicted'
    return df_cm

# Convert confusion matrices to DataFrames with labels
knn_cm_df = confusion_matrix_to_dataframe(knn_cm)
dt_cm_df = confusion_matrix_to_dataframe(dt_cm)
rf_cm_df = confusion_matrix_to_dataframe(rf_cm)
xgb_cm_df = confusion_matrix_to_dataframe(xgb_cm)

# Pembuatan confusion matrices ini bertujuan untuk mengetahui seberapa jauh perbedaan antara hasil prediksi dengan hasil yang sebenarnya

# %%
knn_cm_df

# Sebagai contoh: prediksi menggunakan knn menunjukkan bahwa terdapat 40 orang yang diprediksi tidak survived (0) padahal dia survived (1)
# Out:
# Predicted    0   1
# Actual
# 0          103  33
# 1           40  47

# %%
dt_cm_df
# Out:
# Predicted    0   1
# Actual
# 0          101  35
# 1           44  43

# %%
rf_cm_df
# Out:
# Predicted    0   1
# Actual
# 0          104  32
# 1           43  44

# %%
xgb_cm_df
# Out:
# Predicted    0   1
# Actual
# 0          103  33
# 1           42  45

# %%
def evaluate(y_true, y_pred):
    cm = confusion_matrix(y_true, y_pred)
    accuracy = accuracy_score(y_true, y_pred)
    precision = precision_score(y_true, y_pred, average='weighted')
    recall = recall_score(y_true, y_pred, average='weighted')
    f1 = f1_score(y_true, y_pred, average='weighted')
    return cm, accuracy, precision, recall, f1


# Evaluate KNN
knn_cm, knn_accuracy, knn_precision, knn_recall, knn_f1 = evaluate(y_test, knn_pred)

# Evaluate Decision Tree
dt_cm, dt_accuracy, dt_precision, dt_recall, dt_f1 = evaluate(y_test, dt_pred)

# Evaluate Random Forest
rf_cm, rf_accuracy, rf_precision, rf_recall, rf_f1 = evaluate(y_test, rf_pred)

# Evaluate XGBoost
xgb_cm, xgb_accuracy, xgb_precision, xgb_recall, xgb_f1 = evaluate(y_test, xgb_pred)

# Fungsi-fungsi di atas bertujuan untuk mengetahui akurasi ketepatan hasil prediksi dengan data actual dari tiap model

# %%
knn_f1

# Akurasi knn paling baik dibandingkan dengan pemodelan yang lain karena nilai akurasinya yang paling tinggi
# Out:
# 0.6698916165451054

# %%
dt_f1
# Out:
# 0.6417514757875099

# %%
rf_f1
# Out:
# 0.6588651225404445

# %%
xgb_f1
# Out:
# 0.6598906415704207

# %%
# Nyari faktor mana yang berpengaruh pada penentuan kelompok klasifikasi

xgb_feature_importance = xgb_model.feature_importances_
feature_names = X.columns

xgb_feature_importance_df = pd.DataFrame({'Feature': feature_names, 'Importance': xgb_feature_importance})
xgb_feature_importance_df = xgb_feature_importance_df.sort_values(by='Importance', ascending=False)
xgb_feature_importance_df

# Berdasarkan hasil di bawah ini faktor yang paling memengaruhi dalam pengklasifikasian adalah Pclass (tingkat kelas)
# Out:
#   Feature  Importance
# 0  Pclass    0.494199
# 3   Parch    0.161680
# 2   SibSp    0.120416
# 4    Fare    0.112862
# 1     Age    0.110843

# %%
# Load your new data (data_test) from a CSV file
new_data_uncleaned = pd.read_csv('/content/drive/MyDrive/#dataSET-MSIB/titanic-test.csv')
new_data_uncleaned.set_index("PassengerId", inplace=True)
new_data_uncleaned
# Out:
#              Pclass                                          Name     Sex  \
# PassengerId
# 892               3                              Kelly, Mr. James    male
# 893               3              Wilkes, Mrs. James (Ellen Needs)  female
# 894               2                     Myles, Mr. Thomas Francis    male
# 895               3                              Wirz, Mr. Albert    male
# 896               3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
# ...             ...                                           ...     ...
# 1305              3                            Spector, Mr. Woolf    male
# 1306              1                  Oliva y Ocana, Dona. Fermina  female
# 1307              3                  Saether, Mr. Simon Sivertsen    male
# 1308              3                           Ware, Mr. Frederick    male
# 1309              3                      Peter, Master. Michael J    male
#
# ...

# %%
new_data = new_data_uncleaned.fillna(0)
new_data
# Out:
#              Pclass                                          Name     Sex  \
# PassengerId
# 892               3                              Kelly, Mr. James    male
# 893               3              Wilkes, Mrs. James (Ellen Needs)  female
# 894               2                     Myles, Mr. Thomas Francis    male
# 895               3                              Wirz, Mr. Albert    male
# 896               3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
# ...             ...                                           ...     ...
# 1305              3                            Spector, Mr. Woolf    male
# 1306              1                  Oliva y Ocana, Dona. Fermina  female
# 1307              3                  Saether, Mr. Simon Sivertsen    male
# 1308              3                           Ware, Mr. Frederick    male
# 1309              3                      Peter, Master. Michael J    male
#
# ...

# %%
data_test = new_data.drop(['Name', 'Ticket', 'Cabin', 'Embarked', 'Sex'], axis=1)
data_test
# Out:
#              Pclass   Age  SibSp  Parch      Fare
# PassengerId
# 892               3  34.5      0      0    7.8292
# 893               3  47.0      1      0    7.0000
# 894               2  62.0      0      0    9.6875
# 895               3  27.0      0      0    8.6625
# 896               3  22.0      1      1   12.2875
# ...             ...   ...    ...    ...       ...
# 1305              3   0.0      0      0    8.0500
# 1306              1  39.0      0      0  108.9000
# 1307              3  38.5      0      0    7.2500
# 1308              3   0.0      0      0    8.0500
# 1309              3   0.0      1      1   22.3583
#
# [418 rows x 5 columns]

# %%
# Assuming your new data has the same features as your original data (except the target)

# Make predictions using the trained models
knn_predictions = knn.predict(data_test)
dt_predictions = dt.predict(data_test)
rf_predictions = rf.predict(data_test)
xgb_predictions = xgb_model.predict(data_test)


combined_data = data_test.copy()  # Copy the new dataset

# Add columns for predicted labels
combined_data['KNN_Predictions'] = knn_predictions
combined_data['DT_Predictions'] = dt_predictions
combined_data['RF_Predictions'] = rf_predictions
combined_data['XGB_Predictions'] = xgb_predictions

combined_data
# Out:
#              Pclass   Age  SibSp  Parch      Fare  KNN_Predictions  \
# PassengerId
# 892               3  34.5      0      0    7.8292                0
# 893               3  47.0      1      0    7.0000                0
# 894               2  62.0      0      0    9.6875                0
# 895               3  27.0      0      0    8.6625                1
# 896               3  22.0      1      1   12.2875                0
# ...             ...   ...    ...    ...       ...              ...
# 1305              3   0.0      0      0    8.0500                0
# 1306              1  39.0      0      0  108.9000                1
# 1307              3  38.5      0      0    7.2500                0
# 1308              3   0.0      0      0    8.0500                0
# 1309              3   0.0      1      1   22.3583                0
#
#              DT_Predictions  RF_Predictions  XGB_Predictions
# PassengerId
# 892                       0               0                0
# ...

# %%
# Berdasarkan hasil model pada data train dapat diketahui bahwa prediksi dengan menggunakan model knn lebih baik. Jadi, mungkin prediksi pengelompokkan penumpang
#    pada data_test bisa menggunakan model knn saja

knn_predictions = knn.predict(data_test)

combined_data = data_test.copy()  # Copy the new dataset

# Add columns for predicted labels
combined_data['KNN_Predictions'] = knn_predictions

combined_data
# Out:
#              Pclass   Age  SibSp  Parch      Fare  KNN_Predictions
# PassengerId
# 892               3  34.5      0      0    7.8292                0
# 893               3  47.0      1      0    7.0000                0
# 894               2  62.0      0      0    9.6875                0
# 895               3  27.0      0      0    8.6625                1
# 896               3  22.0      1      1   12.2875                0
# ...             ...   ...    ...    ...       ...              ...
# 1305              3   0.0      0      0    8.0500                0
# 1306              1  39.0      0      0  108.9000                1
# 1307              3  38.5      0      0    7.2500                0
# 1308              3   0.0      0      0    8.0500                0
# 1309              3   0.0      1      1   22.3583                0
#
# [418 rows x 6 columns]
